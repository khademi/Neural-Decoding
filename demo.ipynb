# %%
from nilearn import image
import tensorflow as tf
import numpy as np
import pandas as pd
import nibabel as nib

data_folder = "C:\\Users\\mahmo\\Downloads\\"

tsv_file = "sub-CSI1_ses-01_task-5000scenes_run-01_events.tsv"
data = pd.read_csv (data_folder + tsv_file, sep = '\t')
print(data)
# Out:
#        onset  duration  Subj  Sess  Run  Trial  \
# 0     6.0367    0.9678     1     1    1      1
# 1    16.0122    0.9837     1     1    1      2
# 2    26.0037    1.0009     1     1    1      3
# 3    36.0121    0.9844     1     1    1      4
# 4    46.0038    1.0008     1     1    1      5
# 5    56.0122    0.9843     1     1    1      6
# 6    66.0040    1.0008     1     1    1      7
# 7    75.9953    1.0011     1     1    1      8
# 8    86.0041    1.0007     1     1    1      9
# 9    95.9955    1.0011     1     1    1     10
# 10  106.0041    1.0008     1     1    1     11
# 11  115.9956    1.0011     1     1    1     12
# 12  126.0042    1.0009     1     1    1     13
# 13  135.9957    1.0011     1     1    1     14
# 14  146.0043    1.0008     1     1    1     15
# 15  155.9963    1.0005     1     1    1     16
# 16  166.0044    1.0008     1     1    1     17
# 17  175.9976    0.9994     1     1    1     18
# 18  186.0046    1.0007     1     1    1     19
# ...
