# %%
import tensorflow as tf
import os
import time
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds
import numpy as np
from nilearn import image
from nilearn import plotting
import nibabel as nib
from nilearn.plotting import plot_stat_map, plot_anat, plot_img
from nilearn.image import concat_imgs, mean_img
# Out:
# /localhome/mkhademi/anaconda3/envs/tf/lib/python3.8/site-packages/nilearn/datasets/__init__.py:86: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %%
data_dir = '/local-scratch/localhome/mkhademi/BOLD5000_2.0/'
batch_size = 37
subjs = ['CSI1', 'CSI2', 'CSI3', 'CSI4'] 
sub = subjs[0]
#dataset = tf.data.TFRecordDataset(filenames = [data_dir + 'image_data/' + sub + 'bold5000_coco.tfrecords']).batch(batch_size)
#dataset_size = 2135
dataset = tf.data.TFRecordDataset(filenames = [data_dir + 'image_data/' + sub + 'bold5000_common.tfrecords']).batch(batch_size)
dataset_size = 2864
def tf_parse(eg):
    example = tf.io.parse_example(
        eg, {
            'x': tf.io.FixedLenFeature(shape=(71, 89, 72, 1), dtype=tf.float32),
            'yhat': tf.io.FixedLenFeature(shape=(1000), dtype=tf.float32),
            'y_coco': tf.io.FixedLenFeature(shape=(90), dtype=tf.int64),
            'y_imagenet': tf.io.FixedLenFeature(shape=(1000), dtype=tf.int64),
            'y_super': tf.io.FixedLenFeature(shape=(12), dtype=tf.int64),
            'y_common': tf.io.FixedLenFeature(shape=(90+12+1), dtype=tf.int64)
        })
    return example['x'], example['y_common']
dataset = dataset.unbatch().batch(10)
dataset = dataset.shuffle(512)
dataset = dataset.map(tf_parse)
def train_vis(dataset, j):
    train = dataset.map(lambda x, y:(x, tf.concat([y[:,j:j+1],tf.ones_like(y[:,j:j+1], dtype=tf.int64)-y[:,j:j+1]], axis=1))) 
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(71, 89, 72, 1)),
        # tf.keras.layers.LayerNormalization(),
        tf.keras.layers.Conv3D(1, 3, activation='relu', padding='same', name='conv1'),
        tf.keras.layers.Conv3D(2, 3, activation='relu', padding='same', name='conv2'),
        tf.keras.layers.MaxPooling3D(pool_size=(2, 2, 2)),
        tf.keras.layers.Conv3D(4, 3, padding='same', name='conv3'),
        tf.keras.layers.MaxPooling3D(pool_size=(2, 2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(rate=0.4),
        tf.keras.layers.Dense(2),
        ])
    model.summary()
    model.compile(
        loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True),
        optimizer='adam',
        metrics=[tf.keras.metrics.CategoricalAccuracy()]
    )
    model.fit(train, epochs=60)
    return model

# %%
img4d = image.load_img(data_dir + sub + '_GLMbetas-TYPED-FITHRF-GLMDENOISE-RR_ses-01.nii.gz')
selected_volumes = image.index_img(img4d, slice(200, 201))
imgs = [img for img in image.iter_img(selected_volumes)]
img = imgs[0]
mask = np.zeros(img.shape) * image.get_data(img)
# plot_stat_map(img, threshold='auto', display_mode="z", cut_coords=4, bg_img=None)

# %%
baseline = tf.zeros(shape=(71, 89, 72, 1))
m_steps=30
alphas = tf.linspace(start=0.0, stop=1.0, num=m_steps+1) 
def interpolate_images(baseline, fmri_image, alphas):
    alphas_x = alphas[:, tf.newaxis, tf.newaxis, tf.newaxis, tf.newaxis]
    baseline_x = tf.expand_dims(baseline, axis=0)
    input_x = tf.expand_dims(fmri_image, axis=0)
    delta = input_x - baseline_x
    fmri_images = baseline_x +  alphas_x * delta
    return fmri_images
def compute_gradients(model, images, target_class_idx):
    with tf.GradientTape() as tape:
        tape.watch(images)
        logits = model(images)
        probs = tf.nn.softmax(logits, axis=-1)[:, target_class_idx]
    return tape.gradient(probs, images)
def integral_approximation(gradients):
    # riemann_trapezoidal
    grads = (gradients[:-1] + gradients[1:]) / tf.constant(2.0)
    integrated_gradients = tf.math.reduce_mean(grads, axis=0)
    return integrated_gradients

# %%
def integrated_gradients(model, baseline, fmri_image, target_class_idx, m_steps=30, batch_size=16):
    # Generate alphas.
    alphas = tf.linspace(start=0.0, stop=1.0, num=m_steps+1)
    # Collect gradients.    
    gradient_batches = []
    # Iterate alphas range and batch computation for speed, memory #efficiency, and scaling to larger m_steps.
    for alpha in tf.range(0, len(alphas), batch_size):
        from_ = alpha
        to = tf.minimum(from_ + batch_size, len(alphas))
        alpha_batch = alphas[from_:to]
        gradient_batch = one_batch(model, baseline, fmri_image, alpha_batch, target_class_idx)
        gradient_batches.append(gradient_batch)    
    total_gradients = tf.concat(gradient_batches, axis=0)
    # Integral approximation through averaging gradients.
    avg_gradients = integral_approximation(gradients=total_gradients)
    # Scale integrated gradients with respect to input.
    integrated_gradients = (fmri_image - baseline) * avg_gradients
    return integrated_gradients

@tf.function
def one_batch(model, baseline, fmri_image, alpha_batch, target_class_idx):
    # Generate interpolated inputs between baseline and input.
    interpolated_path_input_batch=interpolate_images(baseline=baseline, fmri_image=fmri_image, alphas=alpha_batch)
    # Compute gradients between model outputs and interpolated inputs.
    gradient_batch = compute_gradients(model, images=interpolated_path_input_batch, target_class_idx=target_class_idx)
    return gradient_batch

# %%
def ig_vis(model, dataset, j):
    train = dataset.map(lambda x, y:(x, tf.concat([y[:,j:j+1],tf.ones_like(y[:,j:j+1],dtype=tf.int64)-y[:,j:j+1]], axis=1)))
    vis_face = np.zeros((71, 89, 72))
    vis_face2 = np.zeros((71, 89, 72))
    count_face = 0
    count_noface = 0
    for x_batch, y_batch in train:
        for i in range(y_batch.shape[0]):
            if y_batch[i][0] == 1:
                ig_attributions = integrated_gradients(model, baseline=baseline, fmri_image=x_batch[i], target_class_idx=0)
                attribution_mask = tf.reduce_sum(tf.math.abs(ig_attributions), axis=-1)
                vis_face += attribution_mask.numpy()
                vis_face2 += tf.reduce_sum(ig_attributions, axis=-1).numpy()
                count_face += 1
            else:
                count_noface += 1
    #vis_face = vis_face/count_face 
    nifti_file = nib.nifti1.Nifti1Image(dataobj=vis_face, affine=img.affine, header=img.header, extra=None,file_map=None)
    plot_stat_map(nifti_file, threshold=0, display_mode="z", cut_coords=4, bg_img=mean_img(img4d))
    plot_stat_map(nifti_file, threshold='auto', display_mode="z", cut_coords=4, bg_img=mean_img(img4d))
    nifti_file = nib.nifti1.Nifti1Image(dataobj=vis_face2, affine=img.affine, header=img.header, extra=None,file_map=None)
    plot_stat_map(nifti_file, threshold=0, display_mode="z", cut_coords=4, bg_img=mean_img(img4d))
    return

# %%
model = train_vis(dataset, j=102)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv3D)              (None, 71, 89, 72, 1)     28
#
#  conv2 (Conv3D)              (None, 71, 89, 72, 2)     56
#
#  max_pooling3d (MaxPooling3D  (None, 35, 44, 36, 2)    0
#  )
#
#  conv3 (Conv3D)              (None, 35, 44, 36, 4)     220
#
#  max_pooling3d_1 (MaxPooling  (None, 17, 22, 18, 4)    0
#  3D)
#
#  flatten (Flatten)           (None, 26928)             0
#
#  dropout (Dropout)           (None, 26928)             0
#
#  dense (Dense)               (None, 2)                 53858
#
# =================================================================
# Total params: 54,162
# Trainable params: 54,162
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 287/287 [==============================] - 30s 79ms/step - loss: 47.2119 - categorical_accuracy: 0.7046
# Epoch 2/60
# 287/287 [==============================] - 27s 77ms/step - loss: 24.9822 - categorical_accuracy: 0.7249
# Epoch 3/60
# 287/287 [==============================] - 28s 80ms/step - loss: 10.2477 - categorical_accuracy: 0.7343
# Epoch 4/60
# 287/287 [==============================] - 29s 83ms/step - loss: 8.6513 - categorical_accuracy: 0.7685
# Epoch 5/60
# 287/287 [==============================] - 29s 83ms/step - loss: 4.2166 - categorical_accuracy: 0.7706
# Epoch 6/60
# 287/287 [==============================] - 28s 84ms/step - loss: 4.7958 - categorical_accuracy: 0.7531
# Epoch 7/60
# 287/287 [==============================] - 29s 83ms/step - loss: 5.3705 - categorical_accuracy: 0.7716
# Epoch 8/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.8786 - categorical_accuracy: 0.7814
# Epoch 9/60
# 287/287 [==============================] - 29s 83ms/step - loss: 3.0019 - categorical_accuracy: 0.7839
# Epoch 10/60
# 287/287 [==============================] - 29s 83ms/step - loss: 3.4133 - categorical_accuracy: 0.7881
# Epoch 11/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.4756 - categorical_accuracy: 0.7943
# Epoch 12/60
# 287/287 [==============================] - 29s 83ms/step - loss: 2.0729 - categorical_accuracy: 0.8034
# Epoch 13/60
# 287/287 [==============================] - 29s 84ms/step - loss: 3.0480 - categorical_accuracy: 0.7968
# Epoch 14/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.2100 - categorical_accuracy: 0.7968
# Epoch 15/60
# 287/287 [==============================] - 29s 83ms/step - loss: 2.5828 - categorical_accuracy: 0.7985
# Epoch 16/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.3630 - categorical_accuracy: 0.8003
# Epoch 17/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.5090 - categorical_accuracy: 0.8066
# Epoch 18/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.7769 - categorical_accuracy: 0.8261
# Epoch 19/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.6153 - categorical_accuracy: 0.8195
# Epoch 20/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.0490 - categorical_accuracy: 0.8104
# Epoch 21/60
# 287/287 [==============================] - 28s 84ms/step - loss: 0.5805 - categorical_accuracy: 0.8258
# Epoch 22/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.6897 - categorical_accuracy: 0.8293
# Epoch 23/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.7347 - categorical_accuracy: 0.8369
# Epoch 24/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.6330 - categorical_accuracy: 0.8258
# Epoch 25/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.0098 - categorical_accuracy: 0.8184
# Epoch 26/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.7994 - categorical_accuracy: 0.8055
# Epoch 27/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.6798 - categorical_accuracy: 0.8265
# Epoch 28/60
# 287/287 [==============================] - 28s 79ms/step - loss: 0.8104 - categorical_accuracy: 0.8076
# Epoch 29/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.4517 - categorical_accuracy: 0.8258
# Epoch 30/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.4359 - categorical_accuracy: 0.8317
# Epoch 31/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.4081 - categorical_accuracy: 0.8341
# Epoch 32/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.5661 - categorical_accuracy: 0.8286
# Epoch 33/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.5920 - categorical_accuracy: 0.8261
# Epoch 34/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.5865 - categorical_accuracy: 0.8352
# Epoch 35/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.7177 - categorical_accuracy: 0.8062
# Epoch 36/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.5238 - categorical_accuracy: 0.8279
# Epoch 37/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.5675 - categorical_accuracy: 0.8191
# Epoch 38/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.5016 - categorical_accuracy: 0.8296
# Epoch 39/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.4533 - categorical_accuracy: 0.8307
# Epoch 40/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.4147 - categorical_accuracy: 0.8338
# Epoch 41/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.4034 - categorical_accuracy: 0.8415
# Epoch 42/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3713 - categorical_accuracy: 0.8467
# Epoch 43/60
# 287/287 [==============================] - 28s 84ms/step - loss: 0.3828 - categorical_accuracy: 0.8460
# Epoch 44/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3832 - categorical_accuracy: 0.8509
# Epoch 45/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.4055 - categorical_accuracy: 0.8439
# Epoch 46/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3443 - categorical_accuracy: 0.8509
# Epoch 47/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3586 - categorical_accuracy: 0.8589
# Epoch 48/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3448 - categorical_accuracy: 0.8534
# Epoch 49/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3449 - categorical_accuracy: 0.8617
# Epoch 50/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3100 - categorical_accuracy: 0.8726
# Epoch 51/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.3082 - categorical_accuracy: 0.8750
# Epoch 52/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2743 - categorical_accuracy: 0.8914
# Epoch 53/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2543 - categorical_accuracy: 0.8935
# Epoch 54/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2816 - categorical_accuracy: 0.8855
# Epoch 55/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2398 - categorical_accuracy: 0.8994
# Epoch 56/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2339 - categorical_accuracy: 0.9071
# Epoch 57/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2534 - categorical_accuracy: 0.8994
# Epoch 58/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2001 - categorical_accuracy: 0.9152
# Epoch 59/60
# 287/287 [==============================] - 28s 84ms/step - loss: 0.1854 - categorical_accuracy: 0.9162
# Epoch 60/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.1718 - categorical_accuracy: 0.9305

# %%
ig_vis(model, dataset, j=102) # tool
# Out:
# /localhome/mkhademi/anaconda3/envs/tf/lib/python3.8/site-packages/nilearn/_utils/niimg.py:61: UserWarning: Non-finite values detected. These values will be replaced with zeros.
#   warn(

# %%
model = train_vis(dataset, j=90)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv3D)              (None, 71, 89, 72, 1)     28
#
#  conv2 (Conv3D)              (None, 71, 89, 72, 2)     56
#
#  max_pooling3d_2 (MaxPooling  (None, 35, 44, 36, 2)    0
#  3D)
#
#  conv3 (Conv3D)              (None, 35, 44, 36, 4)     220
#
#  max_pooling3d_3 (MaxPooling  (None, 17, 22, 18, 4)    0
#  3D)
#
#  flatten_1 (Flatten)         (None, 26928)             0
#
#  dropout_1 (Dropout)         (None, 26928)             0
#
#  dense_1 (Dense)             (None, 2)                 53858
#
# =================================================================
# Total params: 54,162
# Trainable params: 54,162
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 287/287 [==============================] - 29s 81ms/step - loss: 61.0495 - categorical_accuracy: 0.6089
# Epoch 2/60
# 287/287 [==============================] - 29s 83ms/step - loss: 26.3237 - categorical_accuracy: 0.6432
# Epoch 3/60
# 287/287 [==============================] - 29s 83ms/step - loss: 10.9198 - categorical_accuracy: 0.6847
# Epoch 4/60
# 287/287 [==============================] - 29s 84ms/step - loss: 6.9185 - categorical_accuracy: 0.6994
# Epoch 5/60
# 287/287 [==============================] - 29s 84ms/step - loss: 6.4802 - categorical_accuracy: 0.6927
# Epoch 6/60
# 287/287 [==============================] - 29s 83ms/step - loss: 3.7220 - categorical_accuracy: 0.7018
# Epoch 7/60
# 287/287 [==============================] - 29s 83ms/step - loss: 4.1872 - categorical_accuracy: 0.7221
# Epoch 8/60
# 287/287 [==============================] - 28s 84ms/step - loss: 3.9901 - categorical_accuracy: 0.7207
# Epoch 9/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.7027 - categorical_accuracy: 0.7462
# Epoch 10/60
# 287/287 [==============================] - 30s 83ms/step - loss: 1.8457 - categorical_accuracy: 0.7364
# Epoch 11/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.9173 - categorical_accuracy: 0.7556
# Epoch 12/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.9946 - categorical_accuracy: 0.7661
# Epoch 13/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.8291 - categorical_accuracy: 0.7713
# Epoch 14/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.2086 - categorical_accuracy: 0.7566
# Epoch 15/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.1315 - categorical_accuracy: 0.7720
# Epoch 16/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.8720 - categorical_accuracy: 0.7786
# Epoch 17/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.7862 - categorical_accuracy: 0.7786
# Epoch 18/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.7437 - categorical_accuracy: 0.7835
# Epoch 19/60
# 287/287 [==============================] - 28s 83ms/step - loss: 0.5602 - categorical_accuracy: 0.7821
# Epoch 20/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.6838 - categorical_accuracy: 0.7867
# Epoch 21/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.0416 - categorical_accuracy: 0.7580
# Epoch 22/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.9314 - categorical_accuracy: 0.7612
# Epoch 23/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.8222 - categorical_accuracy: 0.7737
# Epoch 24/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.6226 - categorical_accuracy: 0.7902
# Epoch 25/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.5960 - categorical_accuracy: 0.7999
# Epoch 26/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.5729 - categorical_accuracy: 0.7919
# Epoch 27/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.7253 - categorical_accuracy: 0.7877
# Epoch 28/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.5907 - categorical_accuracy: 0.7992
# Epoch 29/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.6279 - categorical_accuracy: 0.8373
# Epoch 30/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3859 - categorical_accuracy: 0.8478
# Epoch 31/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.4840 - categorical_accuracy: 0.8460
# Epoch 32/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.5377 - categorical_accuracy: 0.8558
# Epoch 33/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.4752 - categorical_accuracy: 0.8471
# Epoch 34/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.4799 - categorical_accuracy: 0.8593
# Epoch 35/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3812 - categorical_accuracy: 0.8715
# Epoch 36/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.3339 - categorical_accuracy: 0.8750
# Epoch 37/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3214 - categorical_accuracy: 0.8820
# Epoch 38/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3011 - categorical_accuracy: 0.9071
# Epoch 39/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2688 - categorical_accuracy: 0.9099
# Epoch 40/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3056 - categorical_accuracy: 0.9047
# Epoch 41/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2712 - categorical_accuracy: 0.9054
# Epoch 42/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2235 - categorical_accuracy: 0.9207
# Epoch 43/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.1837 - categorical_accuracy: 0.9263
# Epoch 44/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.1516 - categorical_accuracy: 0.9431
# Epoch 45/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.1749 - categorical_accuracy: 0.9448
# Epoch 46/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.1640 - categorical_accuracy: 0.9413
# Epoch 47/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.1611 - categorical_accuracy: 0.9466
# Epoch 48/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.1114 - categorical_accuracy: 0.9584
# Epoch 49/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0980 - categorical_accuracy: 0.9637
# Epoch 50/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0813 - categorical_accuracy: 0.9717
# Epoch 51/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0877 - categorical_accuracy: 0.9654
# Epoch 52/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0790 - categorical_accuracy: 0.9703
# Epoch 53/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0680 - categorical_accuracy: 0.9721
# Epoch 54/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.0695 - categorical_accuracy: 0.9731
# Epoch 55/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0768 - categorical_accuracy: 0.9731
# Epoch 56/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0949 - categorical_accuracy: 0.9714
# Epoch 57/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0598 - categorical_accuracy: 0.9808
# Epoch 58/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0730 - categorical_accuracy: 0.9728
# Epoch 59/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.0532 - categorical_accuracy: 0.9808
# Epoch 60/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0541 - categorical_accuracy: 0.9773

# %%
ig_vis(model, dataset, j=90) # face

# %%
model = train_vis(dataset, j=92)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv3D)              (None, 71, 89, 72, 1)     28
#
#  conv2 (Conv3D)              (None, 71, 89, 72, 2)     56
#
#  max_pooling3d_4 (MaxPooling  (None, 35, 44, 36, 2)    0
#  3D)
#
#  conv3 (Conv3D)              (None, 35, 44, 36, 4)     220
#
#  max_pooling3d_5 (MaxPooling  (None, 17, 22, 18, 4)    0
#  3D)
#
#  flatten_2 (Flatten)         (None, 26928)             0
#
#  dropout_2 (Dropout)         (None, 26928)             0
#
#  dense_2 (Dense)             (None, 2)                 53858
#
# =================================================================
# Total params: 54,162
# Trainable params: 54,162
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 287/287 [==============================] - 29s 81ms/step - loss: 32.8698 - categorical_accuracy: 0.8586
# Epoch 2/60
# 287/287 [==============================] - 29s 84ms/step - loss: 10.8711 - categorical_accuracy: 0.8635
# Epoch 3/60
# 287/287 [==============================] - 29s 84ms/step - loss: 5.0866 - categorical_accuracy: 0.8792
# Epoch 4/60
# 287/287 [==============================] - 29s 84ms/step - loss: 3.7239 - categorical_accuracy: 0.8911
# Epoch 5/60
# 287/287 [==============================] - 30s 83ms/step - loss: 7.0663 - categorical_accuracy: 0.8872
# Epoch 6/60
# 287/287 [==============================] - 29s 84ms/step - loss: 1.6679 - categorical_accuracy: 0.8987
# Epoch 7/60
# 287/287 [==============================] - 29s 84ms/step - loss: 1.7377 - categorical_accuracy: 0.9096
# Epoch 8/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.3632 - categorical_accuracy: 0.9082
# Epoch 9/60
# 287/287 [==============================] - 29s 84ms/step - loss: 2.3359 - categorical_accuracy: 0.8987
# Epoch 10/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.6590 - categorical_accuracy: 0.9117
# Epoch 11/60
# 287/287 [==============================] - 29s 83ms/step - loss: 3.0917 - categorical_accuracy: 0.8942
# Epoch 12/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.4968 - categorical_accuracy: 0.9022
# Epoch 13/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.0881 - categorical_accuracy: 0.9159
# Epoch 14/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.6863 - categorical_accuracy: 0.9235
# Epoch 15/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.5380 - categorical_accuracy: 0.9256
# Epoch 16/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.7449 - categorical_accuracy: 0.9207
# Epoch 17/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.5784 - categorical_accuracy: 0.9340
# Epoch 18/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.5178 - categorical_accuracy: 0.9396
# Epoch 19/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3220 - categorical_accuracy: 0.9309
# Epoch 20/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.5446 - categorical_accuracy: 0.9284
# Epoch 21/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.6556 - categorical_accuracy: 0.9242
# Epoch 22/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.7576 - categorical_accuracy: 0.9221
# Epoch 23/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.4352 - categorical_accuracy: 0.9221
# Epoch 24/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.3467 - categorical_accuracy: 0.9413
# Epoch 25/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2528 - categorical_accuracy: 0.9361
# Epoch 26/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2211 - categorical_accuracy: 0.9438
# Epoch 27/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2461 - categorical_accuracy: 0.9431
# Epoch 28/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2747 - categorical_accuracy: 0.9427
# Epoch 29/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.5447 - categorical_accuracy: 0.9270
# Epoch 30/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2979 - categorical_accuracy: 0.9375
# Epoch 31/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2578 - categorical_accuracy: 0.9427
# Epoch 32/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.2972 - categorical_accuracy: 0.9392
# Epoch 33/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2164 - categorical_accuracy: 0.9424
# Epoch 34/60
# 287/287 [==============================] - 36s 81ms/step - loss: 0.3021 - categorical_accuracy: 0.9284
# Epoch 35/60
# 287/287 [==============================] - 50s 78ms/step - loss: 0.2179 - categorical_accuracy: 0.9417
# Epoch 36/60
# 287/287 [==============================] - 38s 82ms/step - loss: 0.1548 - categorical_accuracy: 0.9504
# Epoch 37/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.1806 - categorical_accuracy: 0.9399
# Epoch 38/60
# 287/287 [==============================] - 29s 85ms/step - loss: 0.2028 - categorical_accuracy: 0.9438
# Epoch 39/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.1495 - categorical_accuracy: 0.9501
# Epoch 40/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.3567 - categorical_accuracy: 0.9406
# Epoch 41/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2708 - categorical_accuracy: 0.9396
# Epoch 42/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.2606 - categorical_accuracy: 0.9403
# Epoch 43/60
# 287/287 [==============================] - 30s 83ms/step - loss: 0.1837 - categorical_accuracy: 0.9480
# Epoch 44/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.1317 - categorical_accuracy: 0.9522
# Epoch 45/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.1241 - categorical_accuracy: 0.9511
# Epoch 46/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.1178 - categorical_accuracy: 0.9567
# Epoch 47/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.1104 - categorical_accuracy: 0.9647
# Epoch 48/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.2867 - categorical_accuracy: 0.9459
# Epoch 49/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.1551 - categorical_accuracy: 0.9508
# Epoch 50/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.1093 - categorical_accuracy: 0.9630
# Epoch 51/60
# 287/287 [==============================] - 28s 84ms/step - loss: 0.0998 - categorical_accuracy: 0.9616
# Epoch 52/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0867 - categorical_accuracy: 0.9696
# Epoch 53/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.0671 - categorical_accuracy: 0.9724
# Epoch 54/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0579 - categorical_accuracy: 0.9770
# Epoch 55/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.3026 - categorical_accuracy: 0.9466
# Epoch 56/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.1672 - categorical_accuracy: 0.9546
# Epoch 57/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.1125 - categorical_accuracy: 0.9703
# Epoch 58/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0961 - categorical_accuracy: 0.9689
# Epoch 59/60
# 287/287 [==============================] - 29s 84ms/step - loss: 0.0779 - categorical_accuracy: 0.9731
# Epoch 60/60
# 287/287 [==============================] - 29s 83ms/step - loss: 0.0797 - categorical_accuracy: 0.9686

# %%
ig_vis(model, dataset, j=92) # outdoor

# %%
model = train_vis(dataset, j=97)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv3D)              (None, 71, 89, 72, 1)     28
#
#  conv2 (Conv3D)              (None, 71, 89, 72, 2)     56
#
#  max_pooling3d_6 (MaxPooling  (None, 35, 44, 36, 2)    0
#  3D)
#
#  conv3 (Conv3D)              (None, 35, 44, 36, 4)     220
#
#  max_pooling3d_7 (MaxPooling  (None, 17, 22, 18, 4)    0
#  3D)
#
#  flatten_3 (Flatten)         (None, 26928)             0
#
#  dropout_3 (Dropout)         (None, 26928)             0
#
#  dense_3 (Dense)             (None, 2)                 53858
#
# =================================================================
# Total params: 54,162
# Trainable params: 54,162
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 287/287 [==============================] - 31s 88ms/step - loss: 24.4852 - categorical_accuracy: 0.8135
# Epoch 2/60
# 287/287 [==============================] - 29s 83ms/step - loss: 6.3907 - categorical_accuracy: 0.8355
# Epoch 3/60
# 287/287 [==============================] - 29s 84ms/step - loss: 3.3299 - categorical_accuracy: 0.8373
# Epoch 4/60
# 287/287 [==============================] - 31s 83ms/step - loss: 1.6368 - categorical_accuracy: 0.8593
# Epoch 5/60
# 287/287 [==============================] - 29s 84ms/step - loss: 1.1071 - categorical_accuracy: 0.8642
# Epoch 6/60
# 287/287 [==============================] - 29s 83ms/step - loss: 1.8063 - categorical_accuracy: 0.8698
# Epoch 7/60
# 287/287 [==============================] - 28s 82ms/step - loss: 0.8344 - categorical_accuracy: 0.8799
# Epoch 8/60
# 287/287 [==============================] - 28s 81ms/step - loss: 0.5476 - categorical_accuracy: 0.8911
# Epoch 9/60
# 287/287 [==============================] - 28s 81ms/step - loss: 0.8031 - categorical_accuracy: 0.8802
# Epoch 10/60
# 287/287 [==============================] - 28s 81ms/step - loss: 0.5973 - categorical_accuracy: 0.8890
# Epoch 11/60
# 287/287 [==============================] - 28s 81ms/step - loss: 0.5494 - categorical_accuracy: 0.8980
# Epoch 12/60
# 287/287 [==============================] - 28s 80ms/step - loss: 0.4069 - categorical_accuracy: 0.9078
# Epoch 13/60
# 287/287 [==============================] - 28s 80ms/step - loss: 0.4273 - categorical_accuracy: 0.8970
# Epoch 14/60
# 287/287 [==============================] - 28s 81ms/step - loss: 0.4366 - categorical_accuracy: 0.9029
# Epoch 15/60
# 287/287 [==============================] - 28s 80ms/step - loss: 0.3315 - categorical_accuracy: 0.9092
# Epoch 16/60
# 287/287 [==============================] - 28s 80ms/step - loss: 0.4482 - categorical_accuracy: 0.8956
# Epoch 17/60
# 287/287 [==============================] - 28s 80ms/step - loss: 0.3625 - categorical_accuracy: 0.9075
# Epoch 18/60
# 287/287 [==============================] - 28s 80ms/step - loss: 0.4832 - categorical_accuracy: 0.9005
# Epoch 19/60
# 287/287 [==============================] - 28s 80ms/step - loss: 0.3455 - categorical_accuracy: 0.9131
# Epoch 20/60
# 287/287 [==============================] - 28s 79ms/step - loss: 0.3402 - categorical_accuracy: 0.9085
# Epoch 21/60
# 287/287 [==============================] - 28s 79ms/step - loss: 0.2329 - categorical_accuracy: 0.9183
# Epoch 22/60
# 287/287 [==============================] - 28s 79ms/step - loss: 0.2720 - categorical_accuracy: 0.9281
# Epoch 23/60
# 287/287 [==============================] - 28s 79ms/step - loss: 0.2202 - categorical_accuracy: 0.9242
# Epoch 24/60
# 287/287 [==============================] - 28s 79ms/step - loss: 0.1982 - categorical_accuracy: 0.9312
# Epoch 25/60
# 287/287 [==============================] - 27s 79ms/step - loss: 0.2042 - categorical_accuracy: 0.9403
# Epoch 26/60
# 287/287 [==============================] - 28s 79ms/step - loss: 0.6779 - categorical_accuracy: 0.9172
# Epoch 27/60
# 287/287 [==============================] - 27s 79ms/step - loss: 0.2320 - categorical_accuracy: 0.9249
# Epoch 28/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.2050 - categorical_accuracy: 0.9270
# Epoch 29/60
# 287/287 [==============================] - 27s 79ms/step - loss: 0.1790 - categorical_accuracy: 0.9347
# Epoch 30/60
# 287/287 [==============================] - 27s 79ms/step - loss: 0.1725 - categorical_accuracy: 0.9392
# Epoch 31/60
# 287/287 [==============================] - 27s 79ms/step - loss: 0.1767 - categorical_accuracy: 0.9434
# Epoch 32/60
# 287/287 [==============================] - 28s 79ms/step - loss: 0.3203 - categorical_accuracy: 0.9235
# Epoch 33/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.2843 - categorical_accuracy: 0.9239
# Epoch 34/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1656 - categorical_accuracy: 0.9354
# Epoch 35/60
# 287/287 [==============================] - 27s 79ms/step - loss: 0.2367 - categorical_accuracy: 0.9378
# Epoch 36/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1518 - categorical_accuracy: 0.9445
# Epoch 37/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1418 - categorical_accuracy: 0.9480
# Epoch 38/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.2126 - categorical_accuracy: 0.9399
# Epoch 39/60
# 287/287 [==============================] - 27s 79ms/step - loss: 0.1366 - categorical_accuracy: 0.9473
# Epoch 40/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1396 - categorical_accuracy: 0.9497
# Epoch 41/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1231 - categorical_accuracy: 0.9564
# Epoch 42/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1301 - categorical_accuracy: 0.9532
# Epoch 43/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1275 - categorical_accuracy: 0.9560
# Epoch 44/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1288 - categorical_accuracy: 0.9532
# Epoch 45/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1074 - categorical_accuracy: 0.9616
# Epoch 46/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1339 - categorical_accuracy: 0.9518
# Epoch 47/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1277 - categorical_accuracy: 0.9553
# Epoch 48/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1205 - categorical_accuracy: 0.9560
# Epoch 49/60
# 287/287 [==============================] - 28s 78ms/step - loss: 0.1249 - categorical_accuracy: 0.9588
# Epoch 50/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1078 - categorical_accuracy: 0.9612
# Epoch 51/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.0842 - categorical_accuracy: 0.9696
# Epoch 52/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1025 - categorical_accuracy: 0.9633
# Epoch 53/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.0825 - categorical_accuracy: 0.9668
# Epoch 54/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.1106 - categorical_accuracy: 0.9602
# Epoch 55/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.0852 - categorical_accuracy: 0.9710
# Epoch 56/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.0752 - categorical_accuracy: 0.9745
# Epoch 57/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.0708 - categorical_accuracy: 0.9707
# Epoch 58/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.0577 - categorical_accuracy: 0.9787
# Epoch 59/60
# 287/287 [==============================] - 27s 79ms/step - loss: 0.0682 - categorical_accuracy: 0.9731
# Epoch 60/60
# 287/287 [==============================] - 27s 78ms/step - loss: 0.0737 - categorical_accuracy: 0.9717

# %%
ig_vis(model, dataset, j=97) # food
